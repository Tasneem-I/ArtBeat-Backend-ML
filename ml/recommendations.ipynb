# %%
import pandas as pd;
df = pd.read_csv('recseng_type1_dataset.csv')

# %%
df
# Out:
#      userid  artid        artist                 title  \
# 0         1      1         Durer         Self-Portrait
# 1         1      2      de Vinci             Mona Lisa
# 2         1      3  Michelangelo  The Creation of Adam
# 3         1      4       Bruegel        Tower of Babel
# 4         1      5          Hals     Laughing Cavalier
# ..      ...    ...           ...                   ...
# 794      23     76      Computer                  Nest
# 795      23     77      Computer              Splatter
# 796      23     78      Computer             Heidegger
# 797      23     79      Computer                Tunnel
# 798      23     80      Computer               Volcano
#
#                              style  year  \
# 0             Northern Renaissance  1500
# 1                      Renaissance  1503
# 2              Italian Renaissance  1512
# 3    Dutch and Flemish Renaissance  1563
# 4                          Baroque  1624
# ..                             ...   ...
# ...

# %%
from surprise import Dataset, Reader, SVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from surprise import Dataset, Reader, SVD
#       2 from sklearn.feature_extraction.text import TfidfVectorizer
#       3 from sklearn.metrics.pairwise import linear_kernel
#
# ModuleNotFoundError: No module named 'surprise'
